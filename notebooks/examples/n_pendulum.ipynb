# %% [markdown]
# # The $n$-Pendulum System

# %% [markdown]
# ## Contents
#
# ### [1 - Physical Background]
#     [1.1 - Equations of Motion]
#     [1.2 - Simulation]
#
# ### [2 - Class Architecture]
#     [2.1 - Construction]
#     [2.2 - Polymorphism]
#
# ### [3 - Analysis]
#     [3.1 - Sensitivity to Initial Conditions]
